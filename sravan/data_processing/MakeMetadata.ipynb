# %%
import os
from os import listdir
import os.path
import numpy as np
import random
import json

img_dir= "/home/ec2-user/SageMaker/efs/amazon-bin/data/bin-images-resize/"
meta_dir = "/home/ec2-user/SageMaker/efs/amazon-bin/data/metadata/"

# getting whole metadata list 
def get_metadata(img_dir,meta_dir):
    metadata=[]
    n_images=0
#    img_list = listdir(img_dir)
#    N = len(img_list)
    N = 535234
    for i in range(N):
        if i%1000 == 0:
            print("get_metadata: processing (%d/%d)..." % (i,N))
        jpg_path = '%s%05d.jpg' % (img_dir,i+1)
        json_path = '%s%05d.json' % (meta_dir,i+1)
        if os.path.isfile(jpg_path) and os.path.isfile(json_path):
            d = json.loads(open(json_path).read())
            metadata.append(d)
            n_images = n_images + 1
        else:
            metadata.append({})
    print("get_metadata: Available Images: %d" % n_images)
    return metadata,n_images

# getting instance list
def get_instance_data(metadata):
    instances={}
    N = len(metadata)
    for i in range(N):
        if i%1000 == 0:
            print("get_instance_data: processing (%d/%d)..." % (i,N))
        if metadata[i]:
            quantity = metadata[i]['EXPECTED_QUANTITY']
            if quantity>0:
                bin_info = metadata[i]['BIN_FCSKU_DATA']
                bin_keys = bin_info.keys()
                for j in range(0,len(bin_info)):
                    instance_info = bin_info[bin_keys[j]]
                    asin = instance_info['asin']
                    if asin in instances:
                        # occurance
                        instances[asin]['repeat'] = instances[asin]['repeat'] + 1
                        # quantity
                        instances[asin]['quantity'] = instances[asin]['quantity'] + instance_info['quantity']
                        instances[asin]['bin_list'].append(i)
                    else:
                        instances[asin]={}
                        instances[asin]['repeat'] = 1
                        instances[asin]['quantity'] = instance_info['quantity']
                        instances[asin]['name'] = instance_info['name']
                        bin_list = []
                        bin_list.append(i)
                        instances[asin]['bin_list'] = bin_list
    return instances


if __name__ == '__main__':
    metadata,n_images = get_metadata(img_dir, meta_dir)
    instances = get_instance_data(metadata)
    # dumping out all metadata into a file
    print("dumping metadata.json...")
    with open('/home/ec2-user/SageMaker/efs/amazon-bin/input/metadata.json','w') as fp:
        json.dump(metadata,fp)
    #print("dumping instances.json...")
    #with open('/home/ec2-user/SageMaker/efs/amazon-bin/input/instances.json','w') as fp:
        #json.dump(instances,fp)
# Out:
# get_metadata: processing (0/535234)...
# get_metadata: processing (1000/535234)...
# get_metadata: processing (2000/535234)...
# get_metadata: processing (3000/535234)...
# get_metadata: processing (4000/535234)...
# get_metadata: processing (5000/535234)...
# get_metadata: processing (6000/535234)...
# get_metadata: processing (7000/535234)...
# get_metadata: processing (8000/535234)...
# get_metadata: processing (9000/535234)...
# get_metadata: processing (10000/535234)...
# get_metadata: processing (11000/535234)...
# get_metadata: processing (12000/535234)...
# get_metadata: processing (13000/535234)...
# get_metadata: processing (14000/535234)...
# get_metadata: processing (15000/535234)...
# get_metadata: processing (16000/535234)...
# get_metadata: processing (17000/535234)...
# get_metadata: processing (18000/535234)...
# get_metadata: processing (19000/535234)...
# get_metadata: processing (20000/535234)...
# get_metadata: processing (21000/535234)...
# get_metadata: processing (22000/535234)...
# get_metadata: processing (23000/535234)...
# get_metadata: processing (24000/535234)...
# get_metadata: processing (25000/535234)...
# get_metadata: processing (26000/535234)...
# get_metadata: processing (27000/535234)...
# get_metadata: processing (28000/535234)...
# get_metadata: processing (29000/535234)...
# get_metadata: processing (30000/535234)...
# get_metadata: processing (31000/535234)...
# get_metadata: processing (32000/535234)...
# get_metadata: processing (33000/535234)...
# get_metadata: processing (34000/535234)...
# get_metadata: processing (35000/535234)...
# get_metadata: processing (36000/535234)...
# get_metadata: processing (37000/535234)...
# get_metadata: processing (38000/535234)...
# get_metadata: processing (39000/535234)...
# get_metadata: processing (40000/535234)...
# get_metadata: processing (41000/535234)...
# get_metadata: processing (42000/535234)...
